# %% [markdown]
# <a href="https://colab.research.google.com/github/kle59-cyber/BTE-320/blob/main/string_reversal.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Recursive function for string reversal

def reverse(text):
    # Base case: empty string or single character
    if len(text) <= 1:
        return text
    else:
        # Recursive case: last character + reverse of the rest
        return reverse(text[1:]) + text[0]

def main():
    user_input = input("Enter a string to reverse: ")
    result = reverse(user_input)
    print("Reversed string:", result)

if __name__ == "__main__":
    main()
# Out:
# Enter a string to reverse: hello
# Reversed string: olleh
