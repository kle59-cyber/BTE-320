# %% [markdown]
# <a href="https://colab.research.google.com/github/kle59-cyber/BTE-320/blob/main/paarking_garage.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Parking garage fees for 1 to 8 hours

# Base fee is $5
# Each hour adds $2.50

for hours in range(1, 9):   # 1 to 8
    fee = 5 + (2.5 * hours)
    print(hours, fee)
# Out:
# 1 7.5
# 2 10.0
# 3 12.5
# 4 15.0
# 5 17.5
# 6 20.0
# 7 22.5
# 8 25.0
