# %% [markdown]
# <a href="https://colab.research.google.com/github/kle59-cyber/BTE-320/blob/main/roi_calculator.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# ROI Calculator

def roi(cost, revenue):
    # validate cost
    if cost <= 0:
        raise ValueError("Cost must be greater than 0.")

    # calculate ROI
    return (revenue - cost) / cost

def main():
    try:
        cost = float(input("Enter cost: "))
        revenue = float(input("Enter revenue: "))

        result = roi(cost, revenue)
        print("ROI (decimal):", result)
    except ValueError as e:
        print("Error:", e)

if __name__ == "__main__":
    main()
# Out:
# Enter cost: 100
# Enter revenue: 130
# ROI (decimal): 0.3
