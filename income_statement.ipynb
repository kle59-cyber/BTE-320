# %% [markdown]
# <a href="https://colab.research.google.com/github/kle59-cyber/BTE-320/blob/main/income_statement.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Income statement with taxes and net income

sales = float(input("Enter sales ($): "))

# COGS is 40% of sales
cogs = sales * 0.4
gross_profit = sales - cogs

tax_rate = float(input("Enter tax rate (%): "))
tax_rate = tax_rate / 100   # convert percent to decimal

taxes = gross_profit * tax_rate
net_income = gross_profit - taxes

print("Sales: $", sales)
print("Cost of Goods Sold: $", cogs)
print("Gross Profit: $", gross_profit)
print("Taxes: $", taxes)
print("Net Income: $", net_income)
# Out:
# Enter sales ($): 12000
# Enter tax rate (%): 30
# Sales: $ 12000.0
# Cost of Goods Sold: $ 4800.0
# Gross Profit: $ 7200.0
# Taxes: $ 2160.0
# Net Income: $ 5040.0
